# %% [markdown]
# # Exercicio

# %% [markdown]
# Calcular a interpolação cubica de splines para a função (f(x) = cos(x)) no intervalo \([0, 1]\), considerando as condições de contorno natural e fixada. Comparar os resultados obtidos com os valores reais da função em pontos intermediários do intervalo.

# %%
from splines import get_splines
from utils import obter_indice_intervalo
import sympy as sp

# %%
x_a = [0, 0.25, 0.5, 0.75, 1]
x_b = [0, 0.125, 0.25, 0.375, 0.5, 0.625, 0.75, 0.875, 1]
expression = 'cos(x)'
x_eval = 0.5
interval = (0, 1)

# %%
# integral veradeira intervalo [a, b]
expression_sym = sp.sympify(expression)
integral = sp.integrate(expression_sym, (sp.symbols('x'), interval[0], interval[1]))
print(f'Integral verdadeira: {integral.evalf()}')
# Out:
# Integral verdadeira: 0.841470984807897

# %%
# derivada verdadeira no ponto x_eval
expression_deriv = sp.diff(expression_sym, sp.symbols('x'))
deriv_true = expression_deriv.evalf(subs={sp.symbols('x'): x_eval})
print(f'Derivada verdadeira em x={x_eval}: {deriv_true}')
# Out:
# Derivada verdadeira em x=0.5: -0.479425538604203

# %%
# segunda derivada verdadeira
expression_2deriv = sp.diff(expression_deriv, sp.symbols('x'))
deriv2_true = expression_2deriv.evalf(subs={sp.symbols('x'): x_eval})
print(f'Segunda derivada verdadeira em x={x_eval}: {deriv2_true}')
# Out:
# Segunda derivada verdadeira em x=0.5: -0.877582561890373

# %% [markdown]
# ## Spline natural

# %% [markdown]
# ### Expressoes

# %%
splines_a = get_splines(expression, x_a, condicao='natural')
splines_b = get_splines(expression, x_b, condicao='natural')

# %%
print("Splines com condição de contorno natural (x_a):")
for i, spline in enumerate(splines_a):
    print(f"Spline {i}: {spline}")
# Out:
# Splines com condição de contorno natural (x_a):
# Spline 0: -0.835282011620299*x**3 - 0.0721451874311524*x + 1.0
# Spline 1: -0.228760564609958*x + 0.32090404012282*(x - 0.25)**3 - 0.626461508715225*(x - 0.25)**2 + 1.02610256286313
# Spline 2: -0.481821811444541*x - 0.0849134554542168*(x - 0.5)**3 - 0.385783478623109*(x - 0.5)**2 + 1.11849346761264
# Spline 3: -0.690634823653762*x + 0.599291426951698*(x - 0.75)**3 - 0.449468570213774*(x - 0.75)**2 + 1.24966498661414

# %%
print("Splines com condição de contorno natural (x_b):")
for i, spline in enumerate(splines_b):
    print(f"Spline {i}: {spline}")
# Out:
# Splines com condição de contorno natural (x_b):
# Spline 0: -1.68245109963659*x**3 - 0.0361303637335463*x + 1.0
# Spline 1: -0.114995259029912*x + 0.485004171257782*(x - 0.125)**3 - 0.63091916236372*(x - 0.125)**2 + 1.00657207460807
# Spline 2: -0.249990479093596*x - 0.0715260496186497*(x - 0.25)**3 - 0.449042598142052*(x - 0.25)**2 + 1.03141004148404
# Spline 3: -0.365603912205099*x + 0.107938583884666*(x - 0.375)**3 - 0.475864866749046*(x - 0.375)**2 + 1.06760908898923
# Spline 4: -0.479510507772799*x + 0.0626211785982616*(x - 0.5)**3 - 0.435387897792296*(x - 0.5)**2 + 1.11733781577677
# Spline 5: -0.585422114474082*x + 0.173838649609539*(x - 0.625)**3 - 0.411904955817948*(x - 0.625)**2 + 1.17685194105152
# Spline 6: -0.680249666728123*x - 0.124607115459014*(x - 0.75)**3 - 0.34671546221437*(x - 0.75)**2 + 1.24187611891991
# Spline 7: -0.772769490818857*x + 1.049181681364*(x - 0.875)**3 - 0.3934431305115*(x - 0.875)**2 + 1.31717016262983

# %% [markdown]
# ### Integrais

# %%
# integral aproximada usando os splines
integral_spline = 0
for i, spline in enumerate(splines_a):
    a = x_a[i]
    b = x_a[i+1]
    integral_spline += sp.integrate(spline, (sp.symbols('x'), a, b))
    print(f'Integral aproximada do spline {i} no intervalo [{a}, {b}]: {integral_spline.evalf()}')
    
print(f'Integral aproximada total usando splines (x_a): {integral_spline}')
# Out:
# Integral aproximada do spline 0 no intervalo [0, 0.25]: 0.246929757803304
# Integral aproximada do spline 1 no intervalo [0.25, 0.5]: 0.479059658080694
# Integral aproximada do spline 2 no intervalo [0.5, 0.75]: 0.681306154698141
# Integral aproximada do spline 3 no intervalo [0.75, 1]: 0.840890297075019
# Integral aproximada total usando splines (x_a): 0.840890297075019

# %%
# integral aproximada usando os splines
integral_spline = 0
for i, spline in enumerate(splines_b):
    a = x_b[i]
    b = x_b[i+1]
    integral_spline += sp.integrate(spline, (sp.symbols('x'), a, b))
    print(f'Integral aproximada do spline {i} no intervalo [{a}, {b}]: {integral_spline.evalf()}')
    
print(f'Integral aproximada total usando splines (x_b): {integral_spline}')
# Out:
# Integral aproximada do spline 0 no intervalo [0, 0.125]: 0.124615042867582
# Integral aproximada do spline 1 no intervalo [0.125, 0.25]: 0.247360198452455
# Integral aproximada do spline 2 no intervalo [0.25, 0.375]: 0.366224489503253
# Integral aproximada do spline 3 no intervalo [0.375, 0.5]: 0.479378441870567
# Integral aproximada do spline 4 no intervalo [0.5, 0.625]: 0.585050452695683
# Integral aproximada do spline 5 no intervalo [0.625, 0.75]: 0.681589675344704
# Integral aproximada do spline 6 no intervalo [0.75, 0.875]: 0.767503001805477
# Integral aproximada do spline 7 no intervalo [0.875, 1]: 0.841398236525301
# Integral aproximada total usando splines (x_b): 0.841398236525301

# %% [markdown]
# ### Derivadas

# %%
# avaliacao aproximada da derivada no ponto x_eval usando os splines
index_a = obter_indice_intervalo(x_a, x_eval)
spline_a = splines_a[index_a]
deriv_approx_a = sp.diff(spline_a, sp.symbols('x')).evalf(subs={sp.symbols('x'): x_eval})
print(f'Derivada aproximada em x={x_eval} usando splines (x_a): {deriv_approx_a}')
# Out:
# Derivada aproximada em x=0.5 usando splines (x_a): -0.481821811444542

# %%
## segunda derivada
derivada2_approx_a = sp.diff(spline_a, sp.symbols('x'), 2).evalf(subs={sp.symbols('x'): x_eval})
print(f'Segunda derivada aproximada em x={x_eval} usando splines (x_a): {derivada2_approx_a}')
# Out:
# Segunda derivada aproximada em x=0.5 usando splines (x_a): -0.771566957246219

# %%
# avaliacao aproximada da derivada no ponto x_eval usando os splines
index_b = obter_indice_intervalo(x_b, x_eval)
spline_b = splines_b[index_b]
deriv_approx_b = sp.diff(spline_b, sp.symbols('x')).evalf(subs={sp.symbols('x'): x_eval})
print(f'Derivada aproximada em x={x_eval} usando splines (x_b): {deriv_approx_a}')
# Out:
# Derivada aproximada em x=0.5 usando splines (x_b): -0.481821811444542

# %%
# segunda derivada
derivada2_approx_b = sp.diff(spline_b, sp.symbols('x'), 2).evalf(subs={sp.symbols('x'): x_eval})
print(f'Segunda derivada aproximada em x={x_eval} usando splines (x_b): {derivada2_approx_b}')
# Out:
# Segunda derivada aproximada em x=0.5 usando splines (x_b): -0.870775795584592

# %% [markdown]
# ## Spline fixada

# %%
splines_a = get_splines(expression, x_a, condicao='fixada')
splines_b = get_splines(expression, x_b, condicao='fixada')
# Out:
# Derivadas nos extremos [a, b]:
# 0
# -sin(1)
# Derivadas nos extremos [a, b]:
# 0
# -sin(1)

# %%
print("Splines com condição de contorno fixado (x_a):")
for i, spline in enumerate(splines_a):
    print(f"Spline {i}: {spline}")
# Out:
# Splines com condição de contorno fixado (x_a):
# Spline 0: 0.02083847503077*x**3 - 0.502610871387475*x**2 + 2.45636844198316e-14*x + 1.0
# Spline 1: -0.247398221625439*x + 0.0611885779672096*(x - 0.25)**3 - 0.486982015114398*(x - 0.25)**2 + 1.030761977117
# Spline 2: -0.4794163708138*x + 0.0978279065174341*(x - 0.5)**3 - 0.44109058163899*(x - 0.5)**2 + 1.11729074729727
# Spline 3: -0.681618929161274*x + 0.128041441220448*(x - 0.75)**3 - 0.367719651750913*(x - 0.75)**2 + 1.24290306574478

# %%
print("Splines com condição de contorno fixado (x_b):")
for i, spline in enumerate(splines_b):
    print(f"Spline {i}: {spline}")
# Out:
# Splines com condição de contorno fixado (x_b):
# Spline 0: 0.0104166700317522*x**3 - 0.500651381105179*x**2 + 3.53326395918785e-12*x + 1.0
# Spline 1: -0.124674563865657*x + 0.0310874205818747*(x - 0.125)**3 - 0.496745129843272*(x - 0.125)**2 + 1.00778198771254
# Spline 2: -0.247403623488057*x + 0.0512731834910116*(x - 0.25)**3 - 0.485087347125069*(x - 0.25)**2 + 1.03076332758266
# Spline 3: -0.366272029793514*x + 0.0706584020783418*(x - 0.375)**3 - 0.465859903315939*(x - 0.375)**2 + 1.06785963308488
# Spline 4: -0.479424893025021*x + 0.0889426726945444*(x - 0.5)**3 - 0.439363002536561*(x - 0.5)**2 + 1.11729500840288
# Spline 5: -0.58509645587662*x + 0.105832855037286*(x - 0.625)**3 - 0.406009500276107*(x - 0.625)**2 + 1.17664840442811
# Spline 6: -0.681637915865799*x + 0.12109456873425*(x - 0.75)**3 - 0.366322179637127*(x - 0.75)**2 + 1.24291730577317
# Spline 7: -0.767542152865664*x + 0.134380739161898*(x - 0.875)**3 - 0.320911716361779*(x - 0.875)**2 + 1.31259624192078

# %% [markdown]
# ### Integrais

# %%
# integral aproximada usando os splines
integral_spline = 0
for i, spline in enumerate(splines_a):
    a = x_a[i]
    b = x_a[i+1]
    integral_spline += sp.integrate(spline, (sp.symbols('x'), a, b))
    print(f'Integral aproximada do spline {i} no intervalo [{a}, {b}]: {integral_spline.evalf()}')
    
print(f'Integral aproximada total usando splines (x_a): {integral_spline}')
# Out:
# Integral aproximada do spline 0 no intervalo [0, 0.25]: 0.247402585118130
# Integral aproximada do spline 1 no intervalo [0.25, 0.5]: 0.479422885928613
# Integral aproximada do spline 2 no intervalo [0.5, 0.75]: 0.681634953098864
# Integral aproximada do spline 3 no intervalo [0.75, 1]: 0.841466412731435
# Integral aproximada total usando splines (x_a): 0.841466412731435

# %%
# integral aproximada usando os splines
integral_spline = 0
for i, spline in enumerate(splines_b):
    a = x_b[i]
    b = x_b[i+1]
    integral_spline += sp.integrate(spline, (sp.symbols('x'), a, b))
    print(f'Integral aproximada do spline {i} no intervalo [{a}, {b}]: {integral_spline.evalf()}')
    
print(f'Integral aproximada total usando splines (x_b): {integral_spline}')
# Out:
# Integral aproximada do spline 0 no intervalo [0, 0.125]: 0.124674690873537
# Integral aproximada do spline 1 no intervalo [0.125, 0.25]: 0.247403874895333
# Integral aproximada do spline 2 no intervalo [0.25, 0.375]: 0.366272404192478
# Integral aproximada do spline 3 no intervalo [0.375, 0.5]: 0.479425375137479
# Integral aproximada do spline 4 no intervalo [0.5, 0.625]: 0.585097073405500
# Integral aproximada do spline 5 no intervalo [0.625, 0.75]: 0.681638527705217
# Integral aproximada do spline 6 no intervalo [0.75, 0.875]: 0.767543240120299
# Integral aproximada do spline 7 no intervalo [0.875, 1]: 0.841470699372191
# Integral aproximada total usando splines (x_b): 0.841470699372191

# %% [markdown]
# ### Derivadas

# %%
# avaliacao aproximada da derivada no ponto x_eval usando os splines
index_a = obter_indice_intervalo(x_a, x_eval)
spline_a = splines_a[index_a]
deriv_approx_a = sp.diff(spline_a, sp.symbols('x')).evalf(subs={sp.symbols('x'): x_eval})
print(f'Derivada aproximada em x={x_eval} usando splines (x_a): {deriv_approx_a}')
# Out:
# Derivada aproximada em x=0.5 usando splines (x_a): -0.479416370813786

# %%
## segunda derivada
derivada2_approx_a = sp.diff(spline_a, sp.symbols('x'), 2).evalf(subs={sp.symbols('x'): x_eval})
print(f'Segunda derivada aproximada em x={x_eval} usando splines (x_a): {derivada2_approx_a}')
# Out:
# Segunda derivada aproximada em x=0.5 usando splines (x_a): -0.882181163277981

# %%
# avaliacao aproximada da derivada no ponto x_eval usando os splines
index_b = obter_indice_intervalo(x_b, x_eval)
spline_b = splines_b[index_b]
deriv_approx_b = sp.diff(spline_b, sp.symbols('x')).evalf(subs={sp.symbols('x'): x_eval})
print(f'Derivada aproximada em x={x_eval} usando splines (x_b): {deriv_approx_a}')
# Out:
# Derivada aproximada em x=0.5 usando splines (x_b): -0.479416370813786

# %%
# segunda derivada
derivada2_approx_b = sp.diff(spline_b, sp.symbols('x'), 2).evalf(subs={sp.symbols('x'): x_eval})
print(f'Segunda derivada aproximada em x={x_eval} usando splines (x_b): {derivada2_approx_b}')
# Out:
# Segunda derivada aproximada em x=0.5 usando splines (x_b): -0.878726005073122
